# %%
import pandas as pd

# %%
#Method 1: Specify Full Path To File

# %%
stats = pd.read_csv('/Users/Curry/Downloads/P4-Demographic-Data.csv')

# %%
stats
# Out:
#                        Country Name Country Code  Birth rate  Internet users  \
# 0                             Aruba          ABW      10.244        78.90000
# 1                       Afghanistan          AFG      35.253         5.90000
# 2                            Angola          AGO      45.985        19.10000
# 3                           Albania          ALB      12.877        57.20000
# 4              United Arab Emirates          ARE      11.044        88.00000
# 5                         Argentina          ARG      17.716        59.90000
# 6                           Armenia          ARM      13.308        41.90000
# 7               Antigua and Barbuda          ATG      16.447        63.40000
# 8                         Australia          AUS      13.200        83.00000
# 9                           Austria          AUT       9.400        80.61880
# 10                       Azerbaijan          AZE      18.300        58.70000
# ...

# %%
len(stats)
# Out:
# 195

# %%
len(stats.columns)
# Out:
# 5

# %%
stats.head()
# Out:
#            CountryName  CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#           IncomeGroup     mycock
# 0          High income  808.2516
# 1           Low income  207.9927
# 2  Upper middle income  878.3135
# 3  Upper middle income  736.5644
# 4          High income  971.8720

# %%
stats.tail()
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 190       Yemen, Rep.          YEM      32.947            20.0
# 191      South Africa          ZAF      20.850            46.5
# 192  Congo, Dem. Rep.          COD      42.394             2.2
# 193            Zambia          ZMB      40.471            15.4
# 194          Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
# Country Name      195 non-null object
# Country Code      195 non-null object
# Birth rate        195 non-null float64
# Internet users    195 non-null float64
# Income Group      195 non-null object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
stats.describe()
# Out:
#         BirthRate  InternetUsers       mycock
# count  195.000000     195.000000   195.000000
# mean    21.469928      42.076471   653.559009
# std     10.605467      29.030788   351.553521
# min      7.900000       0.900000    28.990400
# 25%     12.120500      14.520000   361.263300
# 50%     19.680000      41.000000   682.074300
# 75%     29.759500      66.225000   892.690170
# max     49.661000      96.546800  1552.589500

# %%
stats.columns=['Country Name ','Country Code','Birth rate','Internet users','Income Group ']

# %%
stats.head(
)
# Out:
#           Country Name  Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#          Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
###Subsegting dataframes in Pandas
#-Rows
#-Columns
#-Combine the two

# %%
#part1. Rows
stats[21:26]
# Out:
#    Country Name  Country Code  Birth rate  Internet users        Income Group
# 21        Belize          BLZ      23.092           33.60  Upper middle income
# 22       Bermuda          BMU      10.400           95.30          High income
# 23       Bolivia          BOL      24.236           36.94  Lower middle income
# 24        Brazil          BRA      14.931           51.04  Upper middle income
# 25      Barbados          BRB      12.188           73.00          High income

# %%
stats[::20]
# Out:
#     CountryName  CountryCode  BirthRate  InternetUsers         IncomeGroup   \
# 0          Aruba         ABW     10.244        78.9000          High income
# 20       Belarus         BLR     12.500        54.1700  Upper middle income
# 40    Costa Rica         CRI     15.022        45.9600  Upper middle income
# 60         Gabon         GAB     30.555         9.2000  Upper middle income
# 80         India         IND     20.291        15.1000  Lower middle income
# 100        Libya         LBY     21.425        16.5000  Upper middle income
# 120   Mozambique         MOZ     39.705         5.4000           Low income
# 140       Poland         POL      9.600        62.8492          High income
# 160     Suriname         SUR     18.455        37.4000  Upper middle income
# 180      Uruguay         URY     14.374        57.6900          High income
#
#         mycock
# 0    808.25160
# 20   677.12500
# 40   690.41112
# 60   281.10600
# 80   306.39410
# 100  353.51250
# 120  214.40700
# ...

# %%
stats['mycock']=stats.BirthRate * stats.InterenetUsers
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-715330e90da6> in <module>
# ----> 1 stats['mycock']=stats.BirthRate * stats.InterenetUsers
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'BirthRate'

# %%
stats.columns=['CountryName ', 'CountryCode', 'BirthRate', 'InternetUsers',
       'IncomeGroup ']

# %%
stats.head()
# Out:
#            CountryName  CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#           IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats['mycock']=stats['BirthRate'] * stats['InternetUsers']

# %%
stats[stats.CountryName == "Malta"]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers IncomeGroup     mycock
# 116       Malta         MLT        9.5        68.9138  High income  654.6811

# %%
### matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.figsize']=10,6
import warnings
warnings.filterwarnings('ignore')

# %%
#Distribution:
vis1 = sns.distplot(stats['InternetUsers'])

# %%
vis1 = sns.distplot(stats['InternetUsers'],bins=30)

# %%
#Boxplots:
vis2 = sns.boxplot(data=stats, x='IncomeGroup ', y='BirthRate')

# %%
vis3 = sns.lmplot(data=stats, x='InternetUsers', y='BirthRate' ,\
                  fit_reg=False, hue='IncomeGroup ', size=7, markers='^', scatter_kws={"s":100})

# %%
###Keyword Arguments in Python (advanced tutorial)

# %%
stats.columns=('CountryCode':'BirthRate')
# Out:
#   File "<ipython-input-162-59e868f5e997>", line 1
#     stats.columns=('CountryCode':'BirthRate')
#                                 ^
# SyntaxError: invalid syntax

# %%
stats[['CountryCode', 'BirthRate']]
# Out:
#     CountryCode  BirthRate
# 0           ABW     10.244
# 1           AFG     35.253
# 2           AGO     45.985
# 3           ALB     12.877
# 4           ARE     11.044
# 5           ARG     17.716
# 6           ARM     13.308
# 7           ATG     16.447
# 8           AUS     13.200
# 9           AUT      9.400
# 10          AZE     18.300
# 11          BDI     44.151
# 12          BEL     11.200
# 13          BEN     36.440
# 14          BFA     40.551
# 15          BGD     20.142
# 16          BGR      9.200
# 17          BHR     15.040
# 18          BHS     15.339
# 19          BIH      9.062
# 20          BLR     12.500
# 21          BLZ     23.092
# 22          BMU     10.400
# 23          BOL     24.236
# 24          BRA     14.931
# 25          BRB     12.188
# 26          BRN     16.405
# 27          BTN     18.134
# 28          BWA     25.267
# 29          CAF     34.076
# ..          ...        ...
# 165         SYC     18.600
# 166         SYR     24.043
# ...

# %%
data = pd.read_csv('/users/Curry/Downloads/P4-Demographic-Data.csv')

# %%
country_data = pd.DataFrame({'CourtryName': np.array(Countries_2012_Dataset),
                                         'CountryCode': np.array(Codes_2012_Dataset),
                             'CoutryRegion': np.array(Regions_2012_Dataset)})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-183-d8fa2323df95> in <module>
# ----> 1 country_data = pd.DataFrame({'CourtryName': np.array(Countries_2012_Dataset),
#       2                                          'CountryCode': np.array(Codes_2012_Dataset),
#       3                              'CoutryRegion': np.array(Regions_2012_Dataset)})
#
# NameError: name 'np' is not defined

# %%
data.columns = ['CountryName','CountryCode','BirthRate','InternetUsers','IncomeGroup']

# %%
data.head
# Out:
# <bound method NDFrame.head of                         CountryName CountryCode  BirthRate  InternetUsers  \
# 0                             Aruba         ABW     10.244       78.90000
# 1                       Afghanistan         AFG     35.253        5.90000
# 2                            Angola         AGO     45.985       19.10000
# 3                           Albania         ALB     12.877       57.20000
# 4              United Arab Emirates         ARE     11.044       88.00000
# 5                         Argentina         ARG     17.716       59.90000
# 6                           Armenia         ARM     13.308       41.90000
# 7               Antigua and Barbuda         ATG     16.447       63.40000
# 8                         Australia         AUS     13.200       83.00000
# 9                           Austria         AUT      9.400       80.61880
# 10                       Azerbaijan         AZE     18.300       58.70000
# ...
